# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Reading a data set to environment

# %%
iris = pd.read_excel('iris.xls')

# %%
iris
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # Displaying the columns

# %%
iris.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %% [markdown]
# # Calculating mean of each column

# %%
np.mean(iris)
# Out:
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %% [markdown]
# # To check for null values

# %%
iris.isnull().sum()
# Out:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %% [markdown]
# # Different type of Visualizations

# %% [markdown]
# # SL vs PL

# %%
plt.figure(figsize=(8,8))
iris[['SL','PL']].plot.kde()
plt.title("SL VS PL",fontsize=16)
plt.xlabel('SL')
plt.ylabel('SW')
# Out:
# Text(0, 0.5, 'SW')

# %% [markdown]
# # SW vs PW

# %%
plt.figure(figsize=(8,8))
iris[['SW','PW']].plot.kde()
plt.title("SW VS PW",fontsize=16)
plt.xlabel('SW')
plt.ylabel('PW')
# Out:
# Text(0, 0.5, 'PW')

# %% [markdown]
# # SW and SL vs Classification

# %%
plt.figure(figsize=(8,10))
plt.subplot(2,1,1)
plt.scatter(iris['Classification'],iris['SW'],s=15,marker='^')
plt.title("SW VS Classification",fontsize=16)
plt.xlabel('Classification')
plt.ylabel('SW')

plt.subplot(2,1,2)
plt.scatter(iris['Classification'],iris['SL'],s=15,marker='^')
plt.title("SL VS Classification",fontsize=16)
plt.xlabel('Classification')
plt.ylabel('SL')
plt.tight_layout()

# %%
plt.figure(figsize=(8,10))

plt.subplot(2,1,1)
plt.scatter(iris['Classification'],iris['PW'],s=15,marker='^')
plt.title("PW VS Classification",fontsize=16)
plt.xlabel('Classification')
plt.ylabel('PW')

plt.subplot(2,1,2)
plt.scatter(iris['Classification'],iris['PL'],s=15,marker='^')
plt.title("PL VS Classification",fontsize=16)
plt.xlabel('Classification')
plt.ylabel('PL')
plt.tight_layout()

# %% [markdown]
# # Extras

# %%
iris1=iris[['SW','SL']]
sns.pairplot(iris1)

# %%
iris2=iris[['PW','PL']]
sns.pairplot(iris2)
